# %%
import torch
from torch import nn
import torchvision
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchmetrics import Accuracy

# %%
train_data_path = "images\\train"
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=8),
    transforms.ColorJitter(brightness=0.08),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_data_path = "images\\test"
torch.manual_seed = 42
torch.cuda.manual_seed = 42
device = "cuda" if torch.cuda.is_available() else "cpu"
train_data = datasets.ImageFolder(root=train_data_path, transform=transform)
test_data = datasets.ImageFolder(root=test_data_path, transform=transform)
train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_data, batch_size=16, shuffle=True)

# %%
def show_img(img):
    img = img.permute(1, 2, 0)
    plt.figure(figsize=(10, 7))
    plt.imshow(img)

# %%
class SkinPredictModel(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2),
        )
        self.block2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU()
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(p=0.55)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=hidden_units * 90 * 90,
                      out_features=output_shape),
        )
        
    def forward(self, x: torch.Tensor):
        return self.classifier(self.block3(self.block2(self.block1(x))))

# %%
skin_predict_model = SkinPredictModel(input_shape=3, hidden_units=32, output_shape=len(train_data.classes)).to(device)
loss_function = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(params=skin_predict_model.parameters(), lr=0.000015, weight_decay=1e-6)
accuracy_function = Accuracy(task="multiclass", num_classes=3).to(device)

# %%
def training_step(model: nn.Module, data_loader: DataLoader, 
                  loss_function: torch.nn, optimizer: torch.optim, 
                  accuracy_function: Accuracy):
    model.train()
    train_loss, train_acc = 0, 0
    for batch, (X, y) in enumerate(data_loader):
        X, y = X.to(device), y.to(device)
        y_pred = model(X)
        loss = loss_function(y_pred, y)
        acc = accuracy_function(torch.argmax(y_pred, dim=1), y)
        train_loss += loss.item() 
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_acc += acc * X.size(0) 
    train_acc = train_acc / len(data_loader.dataset)  
    print(f"Training accuracy: {train_acc * 100:.2f}%, Training loss: {train_loss}")

def testing_step(model: nn.Module, data_loader: DataLoader, 
                 accuracy_function: Accuracy):
    model.eval()
    test_loss, test_acc = 0, 0
    with torch.inference_mode():
        for batch, (X, y) in enumerate(data_loader):
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            loss = loss_function(y_pred, y)
            acc = accuracy_function(torch.argmax(y_pred, dim=1), y)
            test_loss += loss.item() 
            test_acc += acc * X.size(0)
    test_acc = test_acc / len(data_loader.dataset)
    print(f"Testing accuracy: {test_acc * 100:.2f}%, Testing loss: {test_loss}")

# %%
epochs = 81
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    training_step(skin_predict_model, train_loader, loss_function, optimizer, accuracy_function)
    testing_step(skin_predict_model, test_loader, accuracy_function)
# Out:
# Epoch 1/81
# Training accuracy: 34.27%, Training loss: 172.94685530662537
# Testing accuracy: 34.20%, Testing loss: 56.061471819877625
# Epoch 2/81
# Training accuracy: 32.99%, Training loss: 172.73541641235352
# Testing accuracy: 34.20%, Testing loss: 56.03130507469177
# Epoch 3/81
# Training accuracy: 32.95%, Training loss: 172.7972241640091
# Testing accuracy: 34.20%, Testing loss: 55.996679067611694
# Epoch 4/81
# Training accuracy: 32.83%, Training loss: 172.68036675453186
# Testing accuracy: 34.20%, Testing loss: 56.00190269947052
# Epoch 5/81
# Training accuracy: 33.35%, Training loss: 172.67830157279968
# Testing accuracy: 31.60%, Testing loss: 56.222243428230286
# Epoch 6/81
# Training accuracy: 33.27%, Training loss: 172.56339347362518
# Testing accuracy: 34.20%, Testing loss: 56.00823521614075
# Epoch 7/81
# Training accuracy: 34.67%, Training loss: 172.4467669725418
# Testing accuracy: 32.71%, Testing loss: 55.933560729026794
# Epoch 8/81
# Training accuracy: 40.50%, Training loss: 170.33354127407074
# Testing accuracy: 41.51%, Testing loss: 54.80807960033417
# Epoch 9/81
# Training accuracy: 45.86%, Training loss: 165.04464542865753
# Testing accuracy: 46.34%, Testing loss: 53.17894148826599
# Epoch 10/81
# Training accuracy: 49.62%, Training loss: 160.88625395298004
# Testing accuracy: 51.43%, Testing loss: 50.12274390459061
# Epoch 11/81
# Training accuracy: 52.50%, Training loss: 155.49390530586243
# Testing accuracy: 58.36%, Testing loss: 45.503616869449615
# Epoch 12/81
# Training accuracy: 60.26%, Training loss: 142.94796919822693
# Testing accuracy: 75.96%, Testing loss: 35.2254801094532
# Epoch 13/81
# Training accuracy: 67.01%, Training loss: 135.31544774770737
# Testing accuracy: 81.91%, Testing loss: 33.74663791060448
# Epoch 14/81
# Training accuracy: 69.77%, Training loss: 127.15821585059166
# Testing accuracy: 82.03%, Testing loss: 30.7811037003994
# Epoch 15/81
# Training accuracy: 71.85%, Training loss: 121.64197990298271
# Testing accuracy: 78.69%, Testing loss: 30.123791217803955
# Epoch 16/81
# Training accuracy: 73.77%, Training loss: 113.32908475399017
# Testing accuracy: 82.90%, Testing loss: 27.07663482427597
# Epoch 17/81
# Training accuracy: 76.21%, Training loss: 105.505215883255
# Testing accuracy: 82.40%, Testing loss: 26.936825066804886
# Epoch 18/81
# Training accuracy: 78.33%, Training loss: 94.46203655004501
# Testing accuracy: 83.02%, Testing loss: 25.091452807188034
# Epoch 19/81
# Training accuracy: 79.69%, Training loss: 84.37500800192356
# Testing accuracy: 84.26%, Testing loss: 23.063010811805725
# Epoch 20/81
# Training accuracy: 84.41%, Training loss: 71.50561098754406
# Testing accuracy: 90.58%, Testing loss: 15.225148662924767
# Epoch 21/81
# Training accuracy: 87.72%, Training loss: 58.493985414505005
# Testing accuracy: 95.29%, Testing loss: 12.027617752552032
# Epoch 22/81
# Training accuracy: 90.92%, Training loss: 45.86004461720586
# Testing accuracy: 82.65%, Testing loss: 17.624405689537525
# Epoch 23/81
# Training accuracy: 92.80%, Training loss: 38.90398282930255
# Testing accuracy: 97.27%, Testing loss: 6.805870607495308
# Epoch 24/81
# Training accuracy: 94.20%, Training loss: 32.82536838948727
# Testing accuracy: 94.67%, Testing loss: 9.133166901767254
# Epoch 25/81
# Training accuracy: 93.44%, Training loss: 32.61468702554703
# Testing accuracy: 98.27%, Testing loss: 6.100176136940718
# Epoch 26/81
# Training accuracy: 95.24%, Training loss: 25.98239640146494
# Testing accuracy: 91.20%, Testing loss: 10.128309413790703
# Epoch 27/81
# Training accuracy: 96.00%, Training loss: 23.308647274039686
# Testing accuracy: 99.26%, Testing loss: 3.367890488356352
# Epoch 28/81
# Training accuracy: 95.68%, Training loss: 23.552866462618113
# Testing accuracy: 94.67%, Testing loss: 7.536647168919444
# Epoch 29/81
# Training accuracy: 96.60%, Training loss: 19.920532057993114
# Testing accuracy: 99.38%, Testing loss: 3.3833545949310064
# Epoch 30/81
# Training accuracy: 96.60%, Training loss: 20.294549038633704
# Testing accuracy: 97.03%, Testing loss: 4.777418646961451
# Epoch 31/81
# Training accuracy: 97.20%, Training loss: 19.212966622784734
# Testing accuracy: 99.63%, Testing loss: 2.680573352612555
# Epoch 32/81
# Training accuracy: 97.12%, Training loss: 16.567007184959948
# Testing accuracy: 99.13%, Testing loss: 2.6792606385424733
# Epoch 33/81
# Training accuracy: 97.48%, Training loss: 15.28540780255571
# Testing accuracy: 99.75%, Testing loss: 2.520225442945957
# Epoch 34/81
# Training accuracy: 96.84%, Training loss: 16.194077464286238
# Testing accuracy: 96.28%, Testing loss: 6.154878927394748
# Epoch 35/81
# Training accuracy: 97.24%, Training loss: 15.407887697219849
# Testing accuracy: 98.88%, Testing loss: 2.7755284858867526
# Epoch 36/81
# Training accuracy: 97.88%, Training loss: 13.318605601321906
# Testing accuracy: 99.63%, Testing loss: 1.9808675004169345
# Epoch 37/81
# Training accuracy: 98.12%, Training loss: 11.512426984030753
# Testing accuracy: 97.52%, Testing loss: 4.132358246482909
# Epoch 38/81
# Training accuracy: 97.64%, Training loss: 12.954821158200502
# Testing accuracy: 99.26%, Testing loss: 2.2001573322340846
# Epoch 39/81
# Training accuracy: 98.36%, Training loss: 10.393430481897667
# Testing accuracy: 99.26%, Testing loss: 1.8447608179412782
# Epoch 40/81
# Training accuracy: 98.48%, Training loss: 10.39893951988779
# Testing accuracy: 96.90%, Testing loss: 3.9046052107587457
# Epoch 41/81
# Training accuracy: 97.72%, Training loss: 12.427122472785413
# Testing accuracy: 99.38%, Testing loss: 1.7368817208334804
# Epoch 42/81
# Training accuracy: 98.96%, Training loss: 7.145673382678069
# Testing accuracy: 99.88%, Testing loss: 1.1961199708748609
# Epoch 43/81
# Training accuracy: 98.48%, Training loss: 9.338028202648275
# Testing accuracy: 99.38%, Testing loss: 1.2824335803743452
# Epoch 44/81
# Training accuracy: 98.44%, Training loss: 8.637522779172286
# Testing accuracy: 98.27%, Testing loss: 3.2087864393834025
# Epoch 45/81
# Training accuracy: 98.44%, Training loss: 8.058769280207343
# Testing accuracy: 99.01%, Testing loss: 1.8558082235977054
# Epoch 46/81
# Training accuracy: 99.04%, Training loss: 6.6017728198785335
# Testing accuracy: 99.38%, Testing loss: 1.1234816662035882
# Epoch 47/81
# Training accuracy: 99.00%, Training loss: 7.012109973002225
# Testing accuracy: 99.13%, Testing loss: 1.5755666091572493
# Epoch 48/81
# Training accuracy: 99.04%, Training loss: 5.855120700201951
# Testing accuracy: 99.26%, Testing loss: 1.4163817700464278
# Epoch 49/81
# Training accuracy: 98.84%, Training loss: 6.589867944363505
# Testing accuracy: 99.13%, Testing loss: 1.847337762126699
# Epoch 50/81
# Training accuracy: 98.84%, Training loss: 6.563206063816324
# Testing accuracy: 99.75%, Testing loss: 0.8813766562379897
# Epoch 51/81
# Training accuracy: 99.00%, Training loss: 6.050603671523277
# Testing accuracy: 99.88%, Testing loss: 0.8810589271597564
# Epoch 52/81
# Training accuracy: 99.12%, Training loss: 6.2269673141418025
# Testing accuracy: 99.50%, Testing loss: 1.053358740056865
# Epoch 53/81
# Training accuracy: 98.48%, Training loss: 7.795893374364823
# Testing accuracy: 99.38%, Testing loss: 1.0737651798408478
# Epoch 54/81
# Training accuracy: 99.00%, Training loss: 6.584006886580028
# Testing accuracy: 99.38%, Testing loss: 0.9636098088230938
# Epoch 55/81
# Training accuracy: 98.96%, Training loss: 5.737882190500386
# Testing accuracy: 99.38%, Testing loss: 1.330314313294366
# Epoch 56/81
# Training accuracy: 99.24%, Training loss: 4.817874028289225
# Testing accuracy: 98.27%, Testing loss: 2.3601348637603223
# Epoch 57/81
# Training accuracy: 99.36%, Training loss: 3.9201689622423146
# Testing accuracy: 98.02%, Testing loss: 2.7793696802691557
# Epoch 58/81
# Training accuracy: 99.16%, Training loss: 3.6677807404194027
# Testing accuracy: 99.63%, Testing loss: 0.8525950056791771
# Epoch 59/81
# Training accuracy: 99.12%, Training loss: 4.816059286182281
# Testing accuracy: 96.78%, Testing loss: 3.429287076345645
# Epoch 60/81
# Training accuracy: 99.28%, Training loss: 3.912641255170456
# Testing accuracy: 99.38%, Testing loss: 1.1441313001851086
# Epoch 61/81
# Training accuracy: 99.12%, Training loss: 5.310814078722615
# Testing accuracy: 99.88%, Testing loss: 0.4875079701305367
# Epoch 62/81
# Training accuracy: 99.68%, Training loss: 3.3836880645685596
# Testing accuracy: 99.50%, Testing loss: 1.1654697360936552
# Epoch 63/81
# Training accuracy: 99.52%, Training loss: 2.400108272966463
# Testing accuracy: 99.63%, Testing loss: 0.6783953337580897
# Epoch 64/81
# Training accuracy: 99.28%, Training loss: 4.500294184006634
# Testing accuracy: 99.01%, Testing loss: 1.4176605816464871
# Epoch 65/81
# Training accuracy: 99.12%, Training loss: 4.041228759801015
# Testing accuracy: 98.88%, Testing loss: 1.5189632891269866
# Epoch 66/81
# Training accuracy: 99.60%, Training loss: 2.8038448637526017
# Testing accuracy: 99.63%, Testing loss: 0.7121192324339063
# Epoch 67/81
# Training accuracy: 99.60%, Training loss: 2.2726959465799155
# Testing accuracy: 99.75%, Testing loss: 0.5908720381557941
# Epoch 68/81
# Training accuracy: 99.64%, Training loss: 1.9568141959098284
# Testing accuracy: 98.27%, Testing loss: 1.980905788775999
# Epoch 69/81
# Training accuracy: 99.24%, Training loss: 5.043880539167731
# Testing accuracy: 99.38%, Testing loss: 0.9238275919196894
# Epoch 70/81
# Training accuracy: 99.80%, Training loss: 2.4664965761767235
# Testing accuracy: 99.75%, Testing loss: 0.566581497376319
# Epoch 71/81
# Training accuracy: 99.64%, Training loss: 1.608648055796948
# Testing accuracy: 99.63%, Testing loss: 0.537851966029848
# Epoch 72/81
# Training accuracy: 99.04%, Training loss: 5.517108377956902
# Testing accuracy: 99.50%, Testing loss: 1.1484390554978745
# Epoch 73/81
# Training accuracy: 99.56%, Training loss: 2.574233563209418
# Testing accuracy: 99.50%, Testing loss: 0.6051745056574873
# Epoch 74/81
# Training accuracy: 99.72%, Training loss: 2.741576164844446
# Testing accuracy: 99.63%, Testing loss: 0.5196901775925653
# Epoch 75/81
# Training accuracy: 99.64%, Training loss: 2.731115861417493
# Testing accuracy: 99.75%, Testing loss: 0.4980753526324406
# Epoch 76/81
# Training accuracy: 99.76%, Training loss: 1.701267657103017
# Testing accuracy: 99.50%, Testing loss: 0.7724321015411988
# Epoch 77/81
# Training accuracy: 99.76%, Training loss: 1.444300022762036
# Testing accuracy: 98.88%, Testing loss: 1.5532105398451677
# Epoch 78/81
# Training accuracy: 99.80%, Training loss: 1.245176624493979
# Testing accuracy: 99.75%, Testing loss: 0.42500782544811955
# Epoch 79/81
# Training accuracy: 98.16%, Training loss: 8.71075089336955
# Testing accuracy: 99.75%, Testing loss: 0.5336203749466222
# Epoch 80/81
# Training accuracy: 99.84%, Training loss: 1.9913943953324633
# Testing accuracy: 99.63%, Testing loss: 0.9097862284979783
# Epoch 81/81
# Training accuracy: 99.88%, Training loss: 0.761738145534764
# Testing accuracy: 99.88%, Testing loss: 0.2976371185068274

# %%
torch.save(obj=skin_predict_model.state_dict(),
           f="trained_model.pth")
